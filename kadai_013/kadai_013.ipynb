# %%
#kadai_013 関数

def calc(price,rate):
  tax_price =price * ((100+rate)/100)
  return(tax_price)

price = 110
rate = 10
t_price = calc(price,rate)
#出力
print("税抜",price,"円 税込",t_price,"円")
# Out:
# 税抜 110 円 税込 121.00000000000001 円
