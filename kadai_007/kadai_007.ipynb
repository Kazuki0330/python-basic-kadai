# %%
#kadai_007
#リストと辞書
#リスト
day_list = [
    "月曜日は晴れです",
    "月曜日は晴れです",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

#出力
print(day_list[2])

#辞書
day_dic = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

#出力
print(day_dic["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
